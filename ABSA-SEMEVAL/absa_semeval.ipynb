# %% [markdown]
# # Import dependencies

# %%
import torch

from torch.utils.data import DataLoader, RandomSampler

from torch import cuda

# %%
torch.cuda.empty_cache()

# %%
import numpy as np

# %%
import spacy

# %%
import pandas as pd

# %%
from transformers import BertTokenizer

# %%
import BERT_BiLSTM
from ModelDataset import ModelDataset

# %%
from semeval_reader import SemevalReader

# %%
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
model = torch.load('bert_bilstm_model.pth')
model.to(device)
# Out:
# BERT_BiLSTM(
#   (embedding): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (lstm): LSTM(768, 128, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=3, bias=True)
# )

# %% [markdown]
# # Loading data

# %%
semeval_reader = SemevalReader("semeval16_restaurants_train.xml")
reviews = semeval_reader.read_reviews()

# %%
sentences = []

for review in reviews:
    for sentence in review.sentences:
        sentences.append(sentence.text)

# %% [markdown]
# # Aspect extraction

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ### Sentence 0 analysis

# %%
print(f"Sentence: {sentences[0]}")
doc = nlp(sentences[0])
# Out:
# Sentence: judging from previous posts this used to be a good place, but not any longer.

# %%
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="493d40cb64dd4769b15faac550f07a7b-0" class="displacy" width="2675" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">judging</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">previous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">posts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">place,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">longer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M205.0,441.5 L213.0,429.5 197.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-1" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-2" stroke-width="2px" d="M245,439.5 C245,264.5 560.0,264.5 560.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,441.5 L568.0,429.5 552.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-3" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-4" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,441.5 L918.0,429.5 902.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-5" stroke-width="2px" d="M1120,439.5 C1120,352.0 1255.0,352.0 1255.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,441.5 L1112,429.5 1128,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d40cb64dd4769b15faac550f07a7b-0-6" stroke-width="2px" d="M945,439.5 C945,264.5 1260.0,264.5 1260.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d40cb64dd4769b15faac550f07a7b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textP

# %%
for token in doc:
    print(f"\tToken: {token.text}")
    print(f"\t\tDependency: {token.dep_}")
    print(f"\t\tPOS: {token.pos_}")
    print(f"\t\tHead text: {token.head.text}")
    print(f"\t\tHead POS: {token.head.pos_}")
    print(f"\t\tChildren: {[child for child in token.children]}")
# Out:
# 	Token: judging
# 		Dependency: ROOT
# 		POS: VERB
# 		Head text: judging
# 		Head POS: VERB
# 		Children: [from, ,, but, longer, .]
# 	Token: from
# 		Dependency: prep
# 		POS: ADP
# 		Head text: judging
# 		Head POS: VERB
# 		Children: [posts]
# 	Token: previous
# 		Dependency: amod
# 		POS: ADJ
# 		Head text: posts
# 		Head POS: NOUN
# 		Children: []
# 	Token: posts
# 		Dependency: pobj
# 		POS: NOUN
# 		Head text: from
# 		Head POS: ADP
# 		Children: [previous, used]
# 	Token: this
# 		Dependency: nsubj
# 		POS: DET
# 		Head text: used
# 		Head POS: VERB
# 		Children: []
# 	Token: used
# 		Dependency: relcl
# 		POS: VERB
# 		Head text: posts
# 		Head POS: NOUN
# 		Children: [this, be]
# 	Token: to
# 		Dependency: aux
# 		POS: PART
# 		Head text: be
# 		Head POS: VERB
# 		Children: []
# 	Token: be
# 		Dependency: xcomp
# 		POS: VERB
# 		Head text: used
# 		Head POS: VERB
# 		Children: [to, place]
# 	Token: a
# 		Dependency: det
# 		POS: DET
# 		Head text: place
# 		Head POS: NOUN
# 		Children: []
# 	Token: good
# 		Dependency: amod
# 		POS: ADJ
# 		Head text: place
# 		Head POS: NOUN
# 		Children: []
# 	Token: place
# 		Dependency: attr
# 		POS: NOUN
# 		Head text: be
# 		Head POS: VERB
# 		Children: [a, good]
# 	Token: ,
# 		Dependency: punct
# 		POS: PUNCT
# 		Head text: judging
# 		Head POS: VERB
# 		Children: []
# 	Token: but
# 		Dependency: cc
# 		POS: CCONJ
# 		Head text: judging
# 		Head POS: VERB
# 		Children: []
# 	Token: not
# 		Dependency: neg
# 		POS: PART
# 		Head text: any
# 		Head POS: ADV
# 		Children: []
# 	Token: any
# 		Dependency: advmod
# 		POS: ADV
# 		Head text: longer
# 		Head POS: ADV
# 		Children: [not]
# 	Token: longer
# 		Dependency: conj
# 		POS: ADV
# 		Head text: judging
# 		Head POS: VERB
# 		Children: [any]
# 	Token: .
# 		Dependency: punct
# 		POS: PUNCT
# 		Head text: judging
# 		Head POS: VERB
# 		Children: []

# %% [markdown]
# ## Aspect extraction

# %%
ext_aspects = []

for sentence in sentences:
    important = nlp(sentence)
    descriptive_item = ''
    target = ''
    added_terms = ''
    for token in important:
        if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
            target = token.text
        if token.pos_ == 'ADJ':
            added_terms = ''
        for mini_token in token.children:
            if mini_token.pos_ != 'ADV':
                continue
            added_terms += mini_token.text + ' '
        descriptive_item = added_terms + token.text
        ext_aspects.append({'aspect': target, 'description': descriptive_item})

# %%
ext_aspects
# Out:
# [{'aspect': '', 'description': 'longer judging'},
#  {'aspect': '', 'description': 'longer from'},
#  {'aspect': '', 'description': 'previous'},
#  {'aspect': '', 'description': 'posts'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': '', 'description': 'used'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'be'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'good'},
#  {'aspect': '', 'description': 'place'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'but'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'any'},
#  {'aspect': '', 'description': 'any longer'},
#  {'aspect': '', 'description': 'any .'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'there'},
#  {'aspect': '', 'description': 'were'},
#  {'aspect': '', 'description': 'four'},
#  {'aspect': '', 'description': 'of'},
#  {'aspect': '', 'description': 'us'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'arrived'},
#  {'aspect': '', 'description': 'at'},
#  {'aspect': '', 'description': 'noon'},
#  {'aspect': '', 'description': '-'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'place', 'description': 'place'},
#  {'aspect': 'place', 'description': 'was'},
#  {'aspect': 'place', 'description': 'empty'},
#  {'aspect': 'place', 'description': '-'},
#  {'aspect': 'place', 'description': 'and'},
#  {'aspect': 'place', 'description': 'the'},
#  {'aspect': 'staff', 'description': 'staff'},
#  {'aspect': 'staff', 'description': 'acted'},
#  {'aspect': 'staff', 'description': 'like'},
#  {'aspect': 'staff', 'description': 'we'},
#  {'aspect': 'staff', 'description': 'were'},
#  {'aspect': 'staff', 'description': 'imposing'},
#  {'aspect': 'staff', 'description': 'on'},
#  {'aspect': 'staff', 'description': 'them'},
#  {'aspect': 'staff', 'description': 'and'},
#  {'aspect': 'staff', 'description': 'they'},
#  {'aspect': 'staff', 'description': 'were'},
#  {'aspect': 'staff', 'description': 'very'},
#  {'aspect': 'staff', 'description': 'very rude'},
#  {'aspect': 'staff', 'description': 'very .'},
#  {'aspect': '', 'description': 'they'},
#  {'aspect': '', 'description': 'never'},
#  {'aspect': '', 'description': 'never brought'},
#  {'aspect': '', 'description': 'never us'},
#  {'aspect': '', 'description': 'complimentary'},
#  {'aspect': '', 'description': 'noodles'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'ignored'},
#  {'aspect': '', 'description': 'repeated'},
#  {'aspect': '', 'description': 'requests'},
#  {'aspect': '', 'description': 'for'},
#  {'aspect': '', 'description': 'sugar'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'threw'},
#  {'aspect': '', 'description': 'our'},
#  {'aspect': '', 'description': 'dishes'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'table'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'was'},
#  {'aspect': 'food', 'description': 'lousy'},
#  {'aspect': 'food', 'description': '-'},
#  {'aspect': 'food', 'description': 'too'},
#  {'aspect': 'food', 'description': 'too sweet'},
#  {'aspect': 'food', 'description': 'too or'},
#  {'aspect': 'food', 'description': 'too too'},
#  {'aspect': 'food', 'description': 'too salty'},
#  {'aspect': 'food', 'description': 'too and'},
#  {'aspect': 'food', 'description': 'too the'},
#  {'aspect': 'portions', 'description': 'too portions'},
#  {'aspect': 'portions', 'description': 'tiny'},
#  {'aspect': 'portions', 'description': '.'},
#  {'aspect': '', 'description': 'after'},
#  {'aspect': '', 'description': 'all'},
#  {'aspect': '', 'description': 'that'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'they'},
#  {'aspect': '', 'description': 'complained'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'me'},
#  {'aspect': '', 'description': 'about'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'small'},
#  {'aspect': '', 'description': 'tip'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'avoid'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': '', 'description': 'place'},
#  {'aspect': '', 'description': '!'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'have'},
#  {'aspect': '', 'description': 'eaten'},
#  {'aspect': '', 'description': 'at'},
#  {'aspect': '', 'description': 'saul'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'many'},
#  {'aspect': '', 'description': 'times'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'always consistently is'},
#  {'aspect': 'food', 'description': 'always consistently always'},
#  {'aspect': 'food', 'description': 'always consistently consistently'},
#  {'aspect': 'food', 'description': 'always consistently ,'},
#  {'aspect': 'food', 'description': 'always consistently outrageously'},
#  {'aspect': 'food', 'description': 'outrageously good'},
#  {'aspect': 'food', 'description': 'outrageously .'},
#  {'aspect': '', 'description': 'saul'},
#  {'aspect': '', 'description': 'is'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'best'},
#  {'aspect': '', 'description': 'restaurant'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'smith'},
#  {'aspect': '', 'description': 'street'},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'brooklyn'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'duck'},
#  {'aspect': 'confit', 'description': 'confit'},
#  {'aspect': 'confit', 'description': 'always is'},
#  {'aspect': 'confit', 'description': 'always always'},
#  {'aspect': 'confit', 'description': 'amazing'},
#  {'aspect': 'confit', 'description': 'and'},
#  {'aspect': 'confit', 'description': 'the'},
#  {'aspect': 'confit', 'description': 'foie'},
#  {'aspect': 'confit', 'description': 'gras'},
#  {'aspect': 'terrine', 'description': 'terrine'},
#  {'aspect': 'terrine', 'description': 'with'},
#  {'aspect': 'terrine', 'description': 'figs'},
#  {'aspect': 'terrine', 'description': 'was'},
#  {'aspect': 'terrine', 'description': 'out'},
#  {'aspect': 'terrine', 'description': 'of'},
#  {'aspect': 'terrine', 'description': 'this'},
#  {'aspect': 'terrine', 'description': 'world'},
#  {'aspect': 'terrine', 'description': '.'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'wine'},
#  {'aspect': 'list', 'description': 'list'},
#  {'aspect': 'list', 'description': 'is'},
#  {'aspect': 'list', 'description': 'interesting'},
#  {'aspect': 'list', 'description': 'and'},
#  {'aspect': 'list', 'description': 'has'},
#  {'aspect': 'list', 'description': 'many'},
#  {'aspect': 'list', 'description': 'good'},
#  {'aspect': 'list', 'description': 'values'},
#  {'aspect': 'list', 'description': '.'},
#  {'aspect': '', 'description': 'for'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'price'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'you'},
#  {'aspect': '', 'description': 'can'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'well eat'},
#  {'aspect': '', 'description': 'well this'},
#  {'aspect': '', 'description': 'well well'},
#  {'aspect': '', 'description': 'well in'},
#  {'aspect': '', 'description': 'well manhattan'},
#  {'aspect': '', 'description': 'well .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'was'},
#  {'aspect': '', 'description': 'very'},
#  {'aspect': '', 'description': 'very disappointed'},
#  {'aspect': '', 'description': 'very with'},
#  {'aspect': '', 'description': 'very this'},
#  {'aspect': '', 'description': 'very restaurant'},
#  {'aspect': '', 'description': 'very .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 've'},
#  {'aspect': '', 'description': 'asked'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'cart'},
#  {'aspect': '', 'description': 'attendant'},
#  {'aspect': '', 'description': 'for'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'lotus'},
#  {'aspect': '', 'description': 'leaf'},
#  {'aspect': '', 'description': 'wrapped'},
#  {'aspect': '', 'description': 'rice'},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'she'},
#  {'aspect': '', 'description': 'replied'},
#  {'aspect': '', 'description': 'back'},
#  {'aspect': '', 'description': 'rice'},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'just'},
#  {'aspect': '', 'description': 'just away walked'},
#  {'aspect': '', 'description': 'just away away'},
#  {'aspect': '', 'description': 'just away .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'had'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'ask'},
#  {'aspect': '', 'description': 'her'},
#  {'aspect': '', 'description': 'three'},
#  {'aspect': '', 'description': 'times'},
#  {'aspect': '', 'description': 'before'},
#  {'aspect': '', 'description': 'she'},
#  {'aspect': '', 'description': 'finally'},
#  {'aspect': '', 'description': 'finally back came'},
#  {'aspect': '', 'description': 'finally back back'},
#  {'aspect': '', 'description': 'finally back with'},
#  {'aspect': '', 'description': 'finally back the'},
#  {'aspect': '', 'description': 'finally back dish'},
#  {'aspect': '', 'description': 'finally back i'},
#  {'aspect': '', 'description': 'finally back ve'},
#  {'aspect': '', 'description': 'finally back requested'},
#  {'aspect': '', 'description': 'finally back .'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'was'},
#  {'aspect': 'food', 'description': 'okay'},
#  {'aspect': 'food', 'description': ','},
#  {'aspect': 'food', 'description': 'nothing'},
#  {'aspect': 'food', 'description': 'great'},
#  {'aspect': 'food', 'description': '.'},
#  {'aspect': '', 'description': 'chow'},
#  {'aspect': 'fun', 'description': 'fun'},
#  {'aspect': 'fun', 'description': 'was'},
#  {'aspect': 'fun', 'description': 'dry'},
#  {'aspect': 'fun', 'description': ';'},
#  {'aspect': 'fun', 'description': 'pork'},
#  {'aspect': 'fun', 'description': 'shu'},
#  {'aspect': 'fun', 'description': 'mai'},
#  {'aspect': 'fun', 'description': 'was'},
#  {'aspect': 'fun', 'description': 'more'},
#  {'aspect': 'fun', 'description': 'than'},
#  {'aspect': 'fun', 'description': 'usually'},
#  {'aspect': 'fun', 'description': 'usually greasy'},
#  {'aspect': 'fun', 'description': 'usually and'},
#  {'aspect': 'fun', 'description': 'usually had'},
#  {'aspect': 'fun', 'description': 'usually to'},
#  {'aspect': 'fun', 'description': 'usually share'},
#  {'aspect': 'fun', 'description': 'usually a'},
#  {'aspect': 'fun', 'description': 'usually table'},
#  {'aspect': 'fun', 'description': 'usually with'},
#  {'aspect': 'fun', 'description': 'loud'},
#  {'aspect': 'fun', 'description': 'and'},
#  {'aspect': 'fun', 'description': 'rude'},
#  {'aspect': 'fun', 'description': 'family'},
#  {'aspect': 'fun', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': '/'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': 'will'},
#  {'aspect': '', 'description': 'never'},
#  {'aspect': '', 'description': 'never back again go'},
#  {'aspect': '', 'description': 'never back again back'},
#  {'aspect': '', 'description': 'never back again to'},
#  {'aspect': '', 'description': 'never back again this'},
#  {'aspect': '', 'description': 'never back again place'},
#  {'aspect': '', 'description': 'never back again again'},
#  {'aspect': '', 'description': 'never back again .'},
#  {'aspect': '', 'description': 'went'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': '3'},
#  {'aspect': '', 'description': 'day'},
#  {'aspect': '', 'description': 'oyster'},
#  {'aspect': '', 'description': 'binge'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'with'},
#  {'aspect': 'fish', 'description': 'fish'},
#  {'aspect': 'fish', 'description': 'bringing'},
#  {'aspect': 'fish', 'description': 'up'},
#  {'aspect': 'fish', 'description': 'the'},
#  {'aspect': 'fish', 'description': 'closing'},
#  {'aspect': 'fish', 'description': ','},
#  {'aspect': 'fish', 'description': 'and'},
#  {'aspect': 'fish', 'description': 'i'},
#  {'aspect': 'fish', 'description': 'am'},
#  {'aspect': 'fish', 'description': 'so'},
#  {'aspect': 'fish', 'description': 'so glad'},
#  {'aspect': 'fish', 'description': 'so this'},
#  {'aspect': 'fish', 'description': 'so was'},
#  {'aspect': 'fish', 'description': 'so the'},
#  {'aspect': 'fish', 'description': 'so place'},
#  {'aspect': 'fish', 'description': 'so it'},
#  {'aspect': 'fish', 'description': 'so o'},
#  {'aspect': 'trip', 'description': 'so trip'},
#  {'aspect': 'trip', 'description': 'so ended'},
#  {'aspect': 'trip', 'description': 'so ,'},
#  {'aspect': 'trip', 'description': 'so because'},
#  {'aspect': 'trip', 'description': 'so it'},
#  {'aspect': 'trip', 'description': 'so was'},
#  {'aspect': 'trip', 'description': 'so so'},
#  {'aspect': 'trip', 'description': 'so great'},
#  {'aspect': 'trip', 'description': 'so !'},
#  {'aspect': 'service', 'description': 'service'},
#  {'aspect': 'service', 'description': 'was'},
#  {'aspect': 'service', 'description': 'devine'},
#  {'aspect': 'service', 'description': ','},
#  {'aspect': 'service', 'description': 'oysters'},
#  {'aspect': 'service', 'description': 'where'},
#  {'aspect': 'service', 'description': 'a'},
#  {'aspect': 'service', 'description': 'where sensual'},
#  {'aspect': 'service', 'description': 'where as'},
#  {'aspect': 'service', 'description': 'where they'},
#  {'aspect': 'service', 'description': 'where come'},
#  {'aspect': 'service', 'description': 'where ,'},
#  {'aspect': 'service', 'description': 'where and'},
#  {'aspect': 'service', 'description': 'where the'},
#  {'aspect': 'service', 'description': 'where price'},
#  {'aspect': 'service', 'description': 'where can'},
#  {'aspect': 'service', 'description': 'where not'},
#  {'aspect': 'service', 'description': 'where be'},
#  {'aspect': 'service', 'description': 'where beat'},
#  {'aspect': 'service', 'description': 'where !'},
#  {'aspect': 'service', 'description': 'where !'},
#  {'aspect': 'service', 'description': 'where !'},
#  {'aspect': '', 'description': 'you'},
#  {'aspect': '', 'description': 'can'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'wrong here go'},
#  {'aspect': '', 'description': 'wrong here wrong'},
#  {'aspect': '', 'description': 'wrong here here'},
#  {'aspect': '', 'description': 'wrong here .'},
#  {'aspect': '', 'description': 'every'},
#  {'aspect': '', 'description': 'time'},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'new'},
#  {'aspect': '', 'description': 'york'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'make'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'point'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'visit'},
#  {'aspect': '', 'description': 'restaurant'},
#  {'aspect': '', 'description': 'saul'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'smith'},
#  {'aspect': '', 'description': 'street'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'everything'},
#  {'aspect': '', 'description': 'is'},
#  {'aspect': '', 'description': 'always'},
#  {'aspect': '', 'description': 'always cooked'},
#  {'aspect': '', 'description': 'always to'},
#  {'aspect': '', 'description': 'always perfection'},
#  {'aspect': '', 'description': 'always ,'},
#  {'aspect': '', 'description': 'always the'},
#  {'aspect': 'service', 'description': 'always service'},
#  {'aspect': 'service', 'description': 'always is'},
#  {'aspect': 'service', 'description': 'excellent'},
#  {'aspect': 'service', 'description': ','},
#  {'aspect': 'service', 'description': 'the'},
#  {'aspect': 'decor', 'description': 'decor'},
#  {'aspect': 'decor', 'description': 'cool'},
#  {'aspect': 'decor', 'description': 'and'},
#  {'aspect': 'decor', 'description': 'understated'},
#  {'aspect': 'decor', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'had'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'duck'},
#  {'aspect': 'breast', 'description': 'breast'},
#  {'aspect': 'breast', 'description': 'special'},
#  {'aspect': 'breast', 'description': 'on'},
#  {'aspect': 'breast', 'description': 'my'},
#  {'aspect': 'breast', 'description': 'last'},
#  {'aspect': 'breast', 'description': 'visit'},
#  {'aspect': 'breast', 'description': 'and'},
#  {'aspect': 'breast', 'description': 'it'},
#  {'aspect': 'breast', 'description': 'was'},
#  {'aspect': 'breast', 'description': 'incredible'},
#  {'aspect': 'breast', 'description': '.'},
#  {'aspect': '', 'description': 'can'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'wait'},
#  {'aspect': '', 'description': 'wait'},
#  {'aspect': '', 'description': 'for'},
#  {'aspect': '', 'description': 'my'},
#  {'aspect': '', 'description': 'next'},
#  {'aspect': '', 'description': 'visit'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'had'},
#  {'aspect': '', 'description': 'my'},
#  {'aspect': '', 'description': 'eyes'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': '', 'description': 'place'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'promising'},
#  {'aspect': '', 'description': 'myself'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'will'},
#  {'aspect': '', 'description': 'one'},
#  {'aspect': '', 'description': 'day'},
#  {'aspect': '', 'description': "'"},
#  {'aspect': '', 'description': 'give'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'try'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': "'"},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'hate'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'say'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': '', 'description': 'but'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'doubt'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'will'},
#  {'aspect': '', 'description': 'ever'},
#  {'aspect': '', 'description': 'ever back go'},
#  {'aspect': '', 'description': 'ever back back'},
#  {'aspect': '', 'description': 'ever back .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'is'},
#  {'aspect': 'food', 'description': 'very'},
#  {'aspect': 'food', 'description': 'very average'},
#  {'aspect': 'food', 'description': 'very ...'},
#  {'aspect': 'food', 'description': 'very the'},
#  {'aspect': 'food', 'description': 'thai'},
#  {'aspect': 'food', 'description': 'fusion'},
#  {'aspect': 'stuff', 'description': 'stuff'},
#  {'aspect': 'stuff', 'description': 'is'},
#  {'aspect': 'stuff', 'description': 'a'},
#  {'aspect': 'stuff', 'description': 'bit'},
#  {'aspect': 'stuff', 'description': 'too'},
#  {'aspect': 'stuff', 'description': 'too sweet'},
#  {'aspect': 'stuff', 'description': 'too ,'},
#  {'aspect': 'stuff', 'description': 'too every'},
#  {'aspect': 'thing', 'description': 'too thing'},
#  {'aspect': 'thing', 'description': 'too they'},
#  {'aspect': 'thing', 'description': 'too serve'},
#  {'aspect': 'thing', 'description': 'too here is'},
#  {'aspect': 'thing', 'description': 'too here too'},
#  {'aspect': 'thing', 'description': 'too sweet'},
#  {'aspect': 'thing', 'description': 'too here'},
#  {'aspect': 'thing', 'description': 'too .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'only'},
#  {'aspect': 'thing', 'description': 'thing'},
#  {'aspect': 'thing', 'description': 'i'},
#  {'aspect': 'thing', 'description': 'moderately'},
#  {'aspect': 'thing', 'description': 'moderately enjoyed'},
#  {'aspect': 'thing', 'description': 'moderately was'},
#  {'aspect': 'thing', 'description': 'moderately their'},
#  {'aspect': 'thing', 'description': 'moderately grilled'},
#  {'aspect': 'thing', 'description': 'moderately chicken'},
#  {'aspect': 'thing', 'description': 'moderately special'},
#  {'aspect': 'thing', 'description': 'moderately with'},
#  {'aspect': 'thing', 'description': 'moderately edamame'},
#  {'aspect': 'thing', 'description': 'moderately puree'},
#  {'aspect': 'thing', 'description': 'moderately .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'had'},
#  {'aspect': '', 'description': 'never'},
#  {'aspect': '', 'description': 'never before had'},
#  {'aspect': 'edamame', 'description': 'never before edamame'},
#  {'aspect': 'edamame', 'description': 'never before pureed'},
#  {'aspect': 'edamame', 'description': 'never before before'},
#  {'aspect': 'edamame', 'description': 'never before but'},
#  {'aspect': 'edamame', 'description': 'never before i'},
#  {'aspect': 'edamame', 'description': 'never before thought'},
#  {'aspect': 'edamame', 'description': 'never before it'},
#  {'aspect': 'edamame', 'description': 'never before was'},
#  {'aspect': 'edamame', 'description': 'innovative'},
#  {'aspect': 'edamame', 'description': 'and'},
#  {'aspect': 'edamame', 'description': 'tasty'},
#  {'aspect': 'edamame', 'description': '('},
#  {'aspect': 'edamame', 'description': 'could'},
#  {'aspect': 'edamame', 'description': 'have'},
#  {'aspect': 'edamame', 'description': 'used'},
#  {'aspect': 'edamame', 'description': 'a'},
#  {'aspect': 'edamame', 'description': 'bit'},
#  {'aspect': 'edamame', 'description': 'more'},
#  {'aspect': 'edamame', 'description': 'salt'},
#  {'aspect': 'edamame', 'description': ')'},
#  {'aspect': 'edamame', 'description': '.'},
#  {'aspect': '', 'description': 'anyways'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'if'},
#  {'aspect': '', 'description': 'you'},
#  {'aspect': '', 'description': 'are'},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'neighborhood'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'eat'},
#  {'aspect': '', 'description': 'good'},
#  {'aspect': '', 'description': 'food'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'would'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'anyways waste'},
#  {'aspect': '', 'description': 'anyways my'},
#  {'aspect': '', 'description': 'anyways time'},
#  {'aspect': '', 'description': 'anyways trying'},
#  {'aspect': '', 'description': 'anyways to'},
#  {'aspect': '', 'description': 'anyways find'},
#  {'aspect': '', 'description': 'anyways something'},
#  {'aspect': '', 'description': 'anyways ,'},
#  {'aspect': '', 'description': 'anyways rather'},
#  {'aspect': '', 'description': 'anyways rather go'},
#  {'aspect': '', 'description': 'anyways rather across'},
#  {'aspect': '', 'description': 'anyways rather the'},
#  {'aspect': '', 'description': 'anyways rather street'},
#  {'aspect': '', 'description': 'anyways rather to'},
#  {'aspect': '', 'description': 'anyways rather tamari'},
#  {'aspect': '', 'description': 'anyways rather .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'decor', 'description': 'decor'},
#  {'aspect': 'decor', 'description': 'is'},
#  {'aspect': 'decor', 'description': 'night'},
#  {'aspect': 'decor', 'description': 'tho'},
#  {'aspect': 'decor', 'description': '...'},
#  {'aspect': 'decor', 'description': 'but'},
#  {'aspect': 'decor', 'description': 'they'},
#  {'aspect': 'decor', 'description': 'really'},
#  {'aspect': 'decor', 'description': 'really need'},
#  {'aspect': 'decor', 'description': 'really to'},
#  {'aspect': 'decor', 'description': 'really clean'},
#  {'aspect': 'decor', 'description': 'really that'},
#  {'aspect': 'decor', 'description': 'really vent'},
#  {'aspect': 'decor', 'description': 'really in'},
#  {'aspect': 'decor', 'description': 'really the'},
#  {'aspect': 'decor', 'description': 'really ceiling'},
#  {'aspect': 'decor', 'description': 'really ...'},
#  {'aspect': 'decor', 'description': 'really its'},
#  {'aspect': 'decor', 'description': 'really quite'},
#  {'aspect': 'decor', 'description': 'really un'},
#  {'aspect': 'decor', 'description': 'really -'},
#  {'aspect': 'decor', 'description': 'quite appetizing'},
#  {'aspect': 'decor', 'description': 'quite ,'},
#  {'aspect': 'decor', 'description': 'quite and'},
#  {'aspect': 'decor', 'description': 'quite kills'},
#  {'aspect': 'decor', 'description': 'quite your'},
#  {'aspect': 'decor', 'description': 'quite effort'},
#  {'aspect': 'decor', 'description': 'quite to'},
#  {'aspect': 'decor', 'description': 'quite make'},
#  {'aspect': 'decor', 'description': 'quite this'},
#  {'aspect': 'place', 'description': 'quite place'},
#  {'aspect': 'place', 'description': 'quite look'},
#  {'aspect': 'place', 'description': 'sleek'},
#  {'aspect': 'place', 'description': 'and'},
#  {'aspect': 'place', 'description': 'modern'},
#  {'aspect': 'place', 'description': '.'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': 'outside ate'},
#  {'aspect': '', 'description': 'outside outside'},
#  {'aspect': '', 'description': 'outside at'},
#  {'aspect': '', 'description': 'outside haru'},
#  {'aspect': '', 'description': 'outside is'},
#  {'aspect': '', 'description': 'outside sake'},
#  {'aspect': '', 'description': 'outside bar'},
#  {'aspect': '', 'description': 'outside because'},
#  {'aspect': '', 'description': 'outside haru'},
#  {'aspect': '', 'description': 'outside is'},
#  {'aspect': '', 'description': 'outside restaurant'},
#  {'aspect': '', 'description': 'next'},
#  {'aspect': 'door', 'description': 'door'},
#  {'aspect': 'door', 'description': 'was'},
#  {'aspect': 'door', 'description': 'overflowing'},
#  {'aspect': 'door', 'description': '.'},
#  {'aspect': '', 'description': 'what'},
#  {'aspect': '', 'description': 'is'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'difference', 'description': 'difference'},
#  {'aspect': 'difference', 'description': 'between'},
#  {'aspect': 'difference', 'description': 'the'},
#  {'aspect': 'difference', 'description': 'two'},
#  {'aspect': 'difference', 'description': '?'},
#  {'aspect': '', 'description': 'their'},
#  {'aspect': '', 'description': 'sake'},
#  {'aspect': 'list', 'description': 'list'},
#  {'aspect': 'list', 'description': 'was'},
#  {'aspect': 'list', 'description': 'extensive'},
#  {'aspect': 'list', 'description': ','},
#  {'aspect': 'list', 'description': 'but'},
#  {'aspect': 'list', 'description': 'we'},
#  {'aspect': 'list', 'description': 'were'},
#  {'aspect': 'list', 'description': 'looking'},
#  {'aspect': 'list', 'description': 'for'},
#  {'aspect': 'list', 'description': 'purple'},
#  {'aspect': 'list', 'description': 'haze'},
#  {'aspect': 'list', 'description': ','},
#  {'aspect': 'list', 'description': 'which'},
#  {'aspect': 'list', 'description': 'was'},
#  {'aspect': 'list', 'description': 'not'},
#  {'aspect': 'list', 'description': 'listed'},
#  {'aspect': 'list', 'description': 'but'},
#  {'aspect': 'list', 'description': 'made'},
#  {'aspect': 'list', 'description': 'for'},
#  {'aspect': 'list', 'description': 'us'},
#  {'aspect': 'list', 'description': 'upon'},
#  {'aspect': 'list', 'description': 'request'},
#  {'aspect': 'list', 'description': '!'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'spicy'},
#  {'aspect': '', 'description': 'tuna'},
#  {'aspect': 'roll', 'description': 'roll'},
#  {'aspect': 'roll', 'description': 'was'},
#  {'aspect': 'roll', 'description': 'unusually'},
#  {'aspect': 'roll', 'description': 'unusually good'},
#  {'aspect': 'roll', 'description': 'unusually and'},
#  {'aspect': 'roll', 'description': 'unusually the'},
#  {'aspect': 'roll', 'description': 'unusually rock'},
#  {'aspect': 'roll', 'description': 'unusually shrimp'},
#  {'aspect': 'tempura', 'description': 'unusually tempura'},
#  {'aspect': 'tempura', 'description': 'unusually was'},
#  {'aspect': 'tempura', 'description': 'awesome'},
#  {'aspect': 'tempura', 'description': ','},
#  {'aspect': 'tempura', 'description': 'great'},
#  {'aspect': 'tempura', 'description': 'appetizer'},
#  {'aspect': 'tempura', 'description': 'to'},
#  {'aspect': 'tempura', 'description': 'share'},
#  {'aspect': 'tempura', 'description': '!'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': 'around went'},
#  {'aspect': '', 'description': 'around around'},
#  {'aspect': '', 'description': 'around 9:30'},
#  {'aspect': '', 'description': 'around on'},
#  {'aspect': '', 'description': 'around a'},
#  {'aspect': '', 'description': 'around friday'},
#  {'aspect': '', 'description': 'around and'},
#  {'aspect': '', 'description': 'around it'},
#  {'aspect': '', 'description': 'around had'},
#  {'aspect': '', 'description': 'around died'},
#  {'aspect': '', 'description': 'around down'},
#  {'aspect': '', 'description': 'around a'},
#  {'aspect': '', 'description': 'around bit'},
#  {'aspect': '', 'description': 'around then by'},
#  {'aspect': '', 'description': 'around then then'},
#  {'aspect': '', 'description': 'around then so'},
#  {'aspect': '', 'description': 'around then the'},
#  {'aspect': 'service', 'description': 'around then service'},
#  {'aspect': 'service', 'description': 'around then so was'},
#  {'aspect': 'service', 'description': 'great'},
#  {'aspect': 'service', 'description': '!'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': 'love'},
#  {'aspect': '', 'description': 'th'},
#  {'aspect': '', 'description': 'pink'},
#  {'aspect': '', 'description': 'pony'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'perfect'},
#  {'aspect': '', 'description': 'spot'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'food'},
#  {'aspect': '', 'description': '-'},
#  {'aspect': '', 'description': 'awesome'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'service-'},
#  {'aspect': '', 'description': 'friendly'},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'attentive'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'ambiance-'},
#  {'aspect': '', 'description': 'ambiance- relaxed'},
#  {'aspect': '', 'description': 'ambiance- and'},
#  {'aspect': '', 'description': 'stylish'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'do'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'judge'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': '', 'description': 'place'},
#  {'aspect': '', 'description': 'prima'},
#  {'aspect': '', 'description': 'facie'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'you'},
#  {'aspect': '', 'description': 'have'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'try'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'believe'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'away home'},
#  {'aspect': '', 'description': 'away away'},
#  {'aspect': '', 'description': 'away from'},
#  {'aspect': '', 'description': 'away home'},
#  {'aspect': '', 'description': 'away for'},
#  {'aspect': '', 'description': 'away the'},
#  {'aspect': '', 'description': 'literate'},
#  {'aspect': '', 'description': 'heart'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'have'},
#  {'aspect': '', 'description': 'here eaten'},
#  {'aspect': '', 'description': 'here here'},
#  {'aspect': '', 'description': 'here a'},
#  {'aspect': '', 'description': 'here handful'},
#  {'aspect': '', 'description': 'here of'},
#  {'aspect': '', 'description': 'here times'},
#  {'aspect': '', 'description': 'here ,'},
#  {'aspect': '', 'description': 'here for'},
#  {'aspect': '', 'description': 'here no'},
#  {'aspect': '', 'description': 'here reason'},
#  {'aspect': '', 'description': 'here besides'},
#  {'aspect': '', 'description': 'sheer'},
#  {'aspect': '', 'description': 'convenience'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': '('},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'hang'},
#  {'aspect': '', 'description': 'out'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'live'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'neighborhood'},
#  {'aspect': '', 'description': '..'},
#  {'aspect': '', 'description': ')'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'is'},
#  {'aspect': 'food', 'description': 'decent'},
#  {'aspect': 'food', 'description': '.'},
#  {'aspect': '', 'description': 'however'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'however is'},
#  {'aspect': '', 'description': 'however the'},
#  {'aspect': '', 'description': 'however service'},
#  {'aspect': '', 'description': 'however that'},
#  {'aspect': '', 'description': 'however leaves'},
#  {'aspect': '', 'description': 'however a'},
#  {'aspect': '', 'description': 'bad'},
#  {'aspect': '', 'description': 'taste'},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'my'},
#  {'aspect': '', 'description': 'mouth'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'happen'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'have'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'policy'},
#  {'aspect': '', 'description': 'that'},
#  {'aspect': '', 'description': 'along goes'},
#  {'aspect': '', 'description': 'along along'},
#  {'aspect': '', 'description': 'along with'},
#  {'aspect': '', 'description': 'along a'},
#  {'aspect': '', 'description': 'little'},
#  {'aspect': '', 'description': 'bit'},
#  {'aspect': '', 'description': 'of'},
#  {'aspect': '', 'description': 'self'},
#  {'aspect': '', 'description': '-'},
#  {'aspect': '', 'description': 'respect'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'which'},
#  {'aspect': '', 'description': 'includes'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'letting'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': 'waiter', 'description': 'waiter'},
#  {'aspect': 'waiter', 'description': 'intimidate'},
#  {'aspect': 'waiter', 'description': 'me'},
#  {'aspect': 'waiter', 'description': ','},
#  {'aspect': 'waiter', 'description': 'i.e.'},
#  {'aspect': 'waiter', 'description': 'make'},
#  {'aspect': 'waiter', 'description': 'me'},
#  {'aspect': 'waiter', 'description': 'feel'},
#  {'aspect': 'waiter', 'description': 'bad'},
#  {'aspect': 'waiter', 'description': 'asking'},
#  {'aspect': 'waiter', 'description': 'for'},
#  {'aspect': 'waiter', 'description': 'trivialities'},
#  {'aspect': 'waiter', 'description': 'like'},
#  {'aspect': 'waiter', 'description': 'water'},
#  {'aspect': 'waiter', 'description': ','},
#  {'aspect': 'waiter', 'description': 'or'},
#  {'aspect': 'waiter', 'description': 'the'},
#  {'aspect': 'waiter', 'description': 'check'},
#  {'aspect': 'waiter', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'know'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'you'},
#  {'aspect': '', 'description': 'were'},
#  {'aspect': '', 'description': 'too'},
#  {'aspect': '', 'description': 'too busy'},
#  {'aspect': '', 'description': 'too showing'},
#  {'aspect': '', 'description': 'too off'},
#  {'aspect': '', 'description': 'too your'},
#  {'aspect': '', 'description': 'too vintage'},
#  {'aspect': '', 'description': 'too tee'},
#  {'aspect': '', 'description': 'too shirt'},
#  {'aspect': '', 'description': 'too and'},
#  {'aspect': '', 'description': 'too looking'},
#  {'aspect': '', 'description': 'bored'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'but'},
#  {'aspect': '', 'description': 'my'},
#  {'aspect': 'agenda', 'description': 'agenda'},
#  {'aspect': 'agenda', 'description': 'is'},
#  {'aspect': 'agenda', 'description': 'i'},
#  {'aspect': 'agenda', 'description': 'here am'},
#  {'aspect': 'agenda', 'description': 'here here'},
#  {'aspect': 'agenda', 'description': 'here to'},
#  {'aspect': 'agenda', 'description': 'here eat'},
#  {'aspect': 'agenda', 'description': 'here and'},
#  {'aspect': 'agenda', 'description': 'here enjoy'},
#  {'aspect': 'agenda', 'description': 'here the'},
#  {'aspect': 'agenda', 'description': 'here company'},
#  {'aspect': 'agenda', 'description': 'here of'},
#  {'aspect': 'agenda', 'description': 'here friends'},
#  {'aspect': 'agenda', 'description': 'here ,'},
#  {'aspect': 'agenda', 'description': 'here seeking'},
#  {'aspect': 'agenda', 'description': 'here a'},
#  {'aspect': 'agenda', 'description': 'pleasant'},
#  {'aspect': 'agenda', 'description': 'experience'},
#  {'aspect': 'agenda', 'description': '.'},
#  {'aspect': '', 'description': 'well'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'did'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'there find'},
#  {'aspect': '', 'description': 'there it'},
#  {'aspect': '', 'description': 'there there'},
#  {'aspect': '', 'description': 'there ,'},
#  {'aspect': '', 'description': 'there and'},
#  {'aspect': '', 'description': 'there trust'},
#  {'aspect': '', 'description': 'there ,'},
#  {'aspect': '', 'description': 'there i'},
#  {'aspect': '', 'description': 'there have'},
#  {'aspect': '', 'description': 'there told'},
#  {'aspect': '', 'description': 'there everyone'},
#  {'aspect': '', 'description': 'there i'},
#  {'aspect': '', 'description': 'there can'},
#  {'aspect': '', 'description': 'there think'},
#  {'aspect': '', 'description': 'there of'},
#  {'aspect': '', 'description': 'there about'},
#  {'aspect': '', 'description': 'there my'},
#  {'aspect': '', 'description': 'there experience'},
#  {'aspect': '', 'description': 'there .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'last'},
#  {'aspect': 'time', 'description': 'time'},
#  {'aspect': 'time', 'description': 'i'},
#  {'aspect': 'time', 'description': 'walked'},
#  {'aspect': 'time', 'description': 'by'},
#  {'aspect': 'time', 'description': 'it'},
#  {'aspect': 'time', 'description': 'looked'},
#  {'aspect': 'time', 'description': 'pretty'},
#  {'aspect': 'time', 'description': 'pretty empty'},
#  {'aspect': 'time', 'description': 'pretty .'},
#  {'aspect': 'time', 'description': 'pretty hmmm'},
#  {'aspect': 'time', 'description': 'pretty .'},
#  {'aspect': '', 'description': 'this'},
#  {'aspect': 'place', 'description': 'place'},
#  {'aspect': 'place', 'description': 'has'},
#  {'aspect': 'place', 'description': 'got'},
#  {'aspect': 'place', 'description': 'to'},
#  {'aspect': 'place', 'description': 'be'},
#  {'aspect': 'place', 'description': 'the'},
#  {'aspect': 'place', 'description': 'best'},
#  {'aspect': 'place', 'description': 'japanese'},
#  {'aspect': 'place', 'description': 'restaurant'},
#  {'aspect': 'place', 'description': 'in'},
#  {'aspect': 'place', 'description': 'the'},
#  {'aspect': 'place', 'description': 'new'},
#  {'aspect': 'place', 'description': 'york'},
#  {'aspect': 'place', 'description': 'area'},
#  {'aspect': 'place', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'had'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'great'},
#  {'aspect': '', 'description': 'experience'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': 'food', 'description': 'food'},
#  {'aspect': 'food', 'description': 'is'},
#  {'aspect': 'food', 'description': 'great'},
#  {'aspect': 'food', 'description': '.'},
#  {'aspect': 'service', 'description': 'service'},
#  {'aspect': 'service', 'description': 'is'},
#  {'aspect': 'service', 'description': 'top'},
#  {'aspect': 'service', 'description': 'notch'},
#  {'aspect': 'service', 'description': '.'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'have'},
#  {'aspect': '', 'description': 'been'},
#  {'aspect': '', 'description': 'back again going'},
#  {'aspect': '', 'description': 'back again back'},
#  {'aspect': '', 'description': 'back again again again'},
#  {'aspect': '', 'description': 'back again again and'},
#  {'aspect': '', 'description': 'back again again again'},
#  {'aspect': '', 'description': 'back again again .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'tend'},
#  {'aspect': '', 'description': 'to'},
#  {'aspect': '', 'description': 'judge'},
#  {'aspect': '', 'description': 'a'},
#  {'aspect': '', 'description': 'sushi'},
#  {'aspect': '', 'description': 'restaurant'},
#  {'aspect': '', 'description': 'by'},
#  {'aspect': '', 'description': 'its'},
#  {'aspect': '', 'description': 'sea'},
#  {'aspect': '', 'description': 'urchin'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'which'},
#  {'aspect': '', 'description': 'was'},
#  {'aspect': '', 'description': 'heavenly'},
#  {'aspect': '', 'description': 'at'},
#  {'aspect': '', 'description': 'sushi'},
#  {'aspect': '', 'description': 'rose'},
#  {'aspect': '', 'description': '.'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'melted'},
#  {'aspect': '', 'description': 'in'},
#  {'aspect': '', 'description': 'my'},
#  {'aspect': '', 'description': 'little'},
#  {'aspect': '', 'description': 'mouth'},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'perfect'},
#  {'aspect': '', 'description': 'consistency'},
#  {'aspect': '', 'description': '-'},
#  {'aspect': '', 'description': 'not'},
#  {'aspect': '', 'description': 'too'},
#  {'aspect': '', 'description': 'too fishy'},
#  {'aspect': '', 'description': 'too ,'},
#  {'aspect': '', 'description': 'creamy'},
#  {'aspect': '', 'description': ','},
#  {'aspect': '', 'description': 'and'},
#  {'aspect': '', 'description': 'slightly'},
#  {'aspect': '', 'description': 'slightly buttery'},
#  {'aspect': '', 'description': 'slightly .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'sushi', 'description': 'sushi'},
#  {'aspect': 'sushi', 'description': 'seemed'},
#  {'aspect': 'sushi', 'description': 'pretty'},
#  {'aspect': 'sushi', 'description': 'pretty fresh'},
#  {'aspect': 'sushi', 'description': 'pretty and'},
#  {'aspect': 'sushi', 'description': 'pretty was'},
#  {'aspect': 'sushi', 'description': 'pretty adequately'},
#  {'aspect': 'sushi', 'description': 'pretty adequately proportioned'},
#  {'aspect': 'sushi', 'description': 'pretty adequately .'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': 'rice', 'description': 'rice'},
#  {'aspect': 'rice', 'description': 'to'},
#  {'aspect': 'rice', 'description': 'fish'},
#  {'aspect': 'rice', 'description': 'ration'},
#  {'aspect': 'rice', 'description': 'also was'},
#  {'aspect': 'rice', 'description': 'also also'},
#  {'aspect': 'rice', 'description': 'good'},
#  {'aspect': 'rice', 'description': '--'},
#  {'aspect': 'rice', 'description': 'they'},
#  {'aspect': 'rice', 'description': 'did'},
#  {'aspect': 'rice', 'description': 'not'},
#  {'aspect': 'rice', 'description': 'try'},
#  {'aspect': 'rice', 'description': 'to'},
#  {'aspect': 'rice', 'description': 'overpack'},
#  {'aspect': 'rice', 'description': 'the'},
#  {'aspect': 'rice', 'description': 'rice'},
#  {'aspect': 'rice', 'description': '.'},
#  {'aspect': '', 'description': 'we'},
#  {'aspect': '', 'description': 'took'},
#  {'aspect': '', 'description': 'advanatage'},
#  {'aspect': '', 'description': 'of'},
#  {'aspect': '', 'description': 'the'},
#  {'aspect': '', 'description': 'half'},
#  {'aspect': '', 'description': 'price'},
#  {'aspect': '', 'description': 'sushi'},
#  {'aspect': '', 'description': 'deal'},
#  {'aspect': '', 'description': 'on'},
#  {'aspect': '', 'description': 'saturday'},
#  {'aspect': '', 'description': 'so'},
#  {'aspect': '', 'description': 'it'},
#  {'aspect': '', 'description': 'was'},
#  {'aspect': '', 'description': 'well'},
#  {'aspect': '', 'description': 'well worth'},
#  {'aspect': '', 'description': 'well it'},
#  {'aspect': '', 'description': 'well .'},
#  {'aspect': '', 'description': 'i'},
#  {'aspect': '', 'description': 'went'},
#  ...]

# %%
processed_sentences = [sentence.lower() for sentence in sentences]
aspect_feature_pairs = []
for sentence in nlp.pipe(processed_sentences):
    chunks = [(chunk.root.text) for chunk in sentence.noun_chunks if chunk.root.pos_ == 'NOUN']

    terms = ' '.join([token.lemma_ for token in sentence if (not token.is_stop and not token.is_punct and (token.pos_ == "ADJ" or token.pos_ == "VERB"))])

    aspect_feature_pairs.append({'aspect': chunks, 'description': terms})

# %% [markdown]
# # Sentiment prediction

# %%
def predict_sent(dataloader):
    results = []

    for _,data in enumerate(dataloader, 0):
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)

        outputs = model(ids, mask, token_type_ids)

        result = np.argmax(outputs.cpu().detach().numpy(), axis=1)

        results.append(result)

    return results

# %%
df = pd.DataFrame(columns=['text','target_list'])

for aspect_feature_pair in aspect_feature_pairs:
    df = df.append({'text': aspect_feature_pair['description'], 'target_list': [0, 0, 0]}, ignore_index=True)

# %%
df.head()
# Out:
#                                       text target_list
# 0                      judge previous good   [0, 0, 0]
# 1                   arrive act impose rude   [0, 0, 0]
# 2  bring complimentary ignore repeat throw   [0, 0, 0]
# 3                   lousy sweet salty tiny   [0, 0, 0]
# 4                           complain small   [0, 0, 0]

# %%
dataset = ModelDataset(df, tokenizer)

# %%
dataloader = DataLoader(
    dataset,
    sampler = RandomSampler(dataset),
    batch_size = 4
)

# %%
results = predict_sent(dataloader)
